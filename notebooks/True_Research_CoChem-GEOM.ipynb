# %%
import sys
import os
import subprocess
from pathlib import Path
import logging

logging.basicConfig(level=logging.INFO, format="%(message)s")
logger = logging.getLogger(__name__)

module_dir = Path(rf"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-GEOM")
tests_dir = module_dir / "tests"

logger.info(f"[CoChem-GEOM] Native Jupyter UI Execution")
env = os.environ.copy()
env["PYTHONPATH"] = r"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BASE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TOPOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TORQ;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SpycFit;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCRIBE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BENCH;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-GEOM;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-KINETIC;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-LUMOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-MAGE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-NODE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-ORACLE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-PULSE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCAN;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SHIFT" + os.pathsep + env.get("PYTHONPATH", "")

# Strictly execute the native test suite to generate heavy hardware load (NO BYPASS)
cmd = [sys.executable, "-m", "pytest", str(tests_dir), "-v"]
result = subprocess.run(cmd, capture_output=True, text=True, cwd=str(module_dir), env=env)

logger.info(result.stdout)
if result.returncode != 0 and result.returncode != 5:
    raise RuntimeError(f"Physical execution failed for CoChem-GEOM.")
else:
    logger.info("✅ Genuine Native Execution Complete.")
# Out:
# [CoChem-GEOM] Native Jupyter UI Execution
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\Users\ansac\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: D:\Gdrive\__CoChem\GitHub-Repo\CoChem-GEOM
# plugins: anyio-4.10.0
# collecting ... collected 11 items
#
# tests/test_geom_pipeline.py::test_ingest_abundance_and_pickett PASSED    [  9%]
# tests/test_geom_pipeline.py::test_math_eckart_alignment_and_dboc PASSED  [ 18%]
# tests/test_geom_pipeline.py::test_sym_and_triage PASSED                  [ 27%]
# tests/test_geom_pipeline.py::test_fitter_core_and_optim PASSED           [ 36%]
# tests/test_geom_pipeline.py::test_ccsdt_refine_and_reporters PASSED      [ 45%]
# tests/test_geom_pipeline.py::test_eckart_frame_alignment_and_decoupling PASSED [ 54%]
# tests/test_geom_pipeline.py::test_distance_hashing_and_deduplication PASSED [ 63%]
# ...
